# %%
import pandas as pd

# %%
dataset = pd.read_csv('CKD.csv')
dataset.shape
# Out:
# (399, 25)

# %%
dataset['classification'].value_counts()
# Out:
# classification
# yes    249
# no     150
# Name: count, dtype: int64

# %%
dataset['ba'].value_counts()
# Out:
# ba
# notpresent    377
# present        22
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# dataset = pd.get_dummies(dataset, drop_first=True)
# dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
from sklearn.preprocessing import  LabelEncoder
lable_encoder = LabelEncoder()
nominal_cols = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']

for cols in nominal_cols:
    dataset[cols] = lable_encoder.fit_transform(dataset[cols])
ordinal_mapping = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
dataset['sg'] = dataset['sg'].map(ordinal_mapping)

dataset['sg'].value_counts()
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    1
# 397    1
# 398    1
# Name: rbc, Length: 399, dtype: int64

# %%
dependent_variable = dataset['classification']
independent_variable = dataset.drop('classification', axis=1)

independent_variable
# Out:
#            age         bp  sg   al   su  rbc  pc  pcc  ba         bgr  ...  \
# 0     2.000000  76.459948   3  3.0  0.0    1   0    0   0  148.112676  ...
# 1     3.000000  76.459948   3  2.0  0.0    1   1    0   0  148.112676  ...
# 2     4.000000  76.459948   1  1.0  0.0    1   1    0   0   99.000000  ...
# 3     5.000000  76.459948   4  1.0  0.0    1   1    0   0  148.112676  ...
# 4     5.000000  50.000000   3  0.0  0.0    1   1    0   0  148.112676  ...
# ..         ...        ...  ..  ...  ...  ...  ..  ...  ..         ...  ...
# 394  51.492308  70.000000   1  0.0  0.0    1   1    0   0  219.000000  ...
# 395  51.492308  70.000000   3  0.0  2.0    1   1    0   0  220.000000  ...
# 396  51.492308  70.000000   3  3.0  0.0    1   1    0   0  110.000000  ...
# 397  51.492308  90.000000   1  0.0  0.0    1   1    0   0  207.000000  ...
# 398  51.492308  80.000000   1  0.0  0.0    1   1    0   0  100.000000  ...
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent_variable,dependent_variable, test_size=0.3, random_state=0)

x_train['su'].value_counts()
# Out:
# su
# 0.0    239
# 2.0     12
# 3.0      9
# 1.0      9
# 4.0      8
# 5.0      2
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.naive_bayes import GaussianNB

grid_params = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan','minkowski'],
    'p': [1, 2]
}
model = KNeighborsClassifier()
grid_search = GridSearchCV(estimator=model, param_grid=grid_params, refit=True, verbose=3,n_jobs=-1 ,scoring='f1_weighted')
grid_search.fit(x_train, y_train)
y_pred = grid_search.predict(x_test)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the test scores are non-finite: [0.96466415 0.9681756  0.96466415 0.9681756  0.94353729 0.95053438
#  0.94353729 0.95053438 0.94003765 0.94003765 0.94003765 0.94003765
#  0.93302858 0.94003765 0.93302858 0.94003765 0.92600611 0.93303161
#  0.92600611 0.93303161        nan 0.9681756         nan 0.9681756
#         nan 0.96104293        nan 0.96104293        nan 0.96104293
#         nan 0.96104293        nan 0.95403486        nan 0.95403486
#         nan 0.95400169        nan 0.95400169        nan 0.9681756
#  0.96466415 0.9681756         nan 0.96104293 0.94353729 0.95053438
#         nan 0.96104293 0.94003765 0.94003765        nan 0.95403486
#  0.93302858 0.94003765        nan 0.95400169 0.92600611 0.93303161]
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[45,  0],
#        [ 5, 70]])

# %%
cls_report = classification_report(y_test, y_pred)
print(cls_report)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.90      1.00      0.95        45
#          yes       1.00      0.93      0.97        75
#
#     accuracy                           0.96       120
#    macro avg       0.95      0.97      0.96       120
# weighted avg       0.96      0.96      0.96       120
